# %%
import pickle

with open('../log_history.pkl', 'rb') as f:
    log_history = pickle.load(f)
    
losses = [log["loss"] for log in log_history[:-1]]
len(losses)
# Out:
# 1000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = list(range(1, len(losses) + 1))

# Apply Seaborn styles for a cleaner look
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='red', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = list(range(1, len(losses) + 1))

# Apply Seaborn styles for a cleaner look
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='red', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = list(range(1, len(losses) + 1))

# Apply Seaborn styles for a cleaner look
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='red', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import pickle

with open('../losses_ft.pkl', 'rb') as f:
    losses = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = [step * 100 for step in range(1, len(losses) + 1)]

# Apply Seaborn styles for a cleaner look
sns.set_theme()

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='blue', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = list(range(1, len(losses) + 1))

# Apply Seaborn styles for a cleaner look
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='blue', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

steps = list(range(1, len(losses) + 1))

# Apply Seaborn styles for a cleaner look
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='blue', linestyle='-', marker='o')

# Add title and labels
plt.title('Training and Validation Loss over every 200 Steps', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#steps = list(range(1, len(losses) + 1))
steps = [step * 200 for step in range(1, len(losses) + 1)]

# Apply Seaborn styles for a cleaner look
sns.set_theme()

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='red', linestyle='-', marker='o')

# Add title and labels
plt.title('Training Loss with Knowledge Distillation', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import pickle

with open('../losses_kd.pkl', 'rb') as f:
    losses = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#steps = list(range(1, len(losses) + 1))
steps = [step * 200 for step in range(1, len(losses) + 1)]

# Apply Seaborn styles for a cleaner look
sns.set_theme()

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, losses, label='Training Loss', color='red', linestyle='-', marker='o')

# Add title and labels
plt.title('Training Loss with Knowledge Distillation', fontsize=16)
plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)

# Show legend and grid
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Value 1', 'Value 2', 'Value 3']
results_1 = [10, 20, 15]
results_2 = [12, 18, 17]
results_3 = [14, 22, 13]

# Set the width of each bar and the position on the x-axis
bar_width = 0.2
x = np.arange(len(categories))

# Plot each group of bars
plt.bar(x - bar_width, results_1, width=bar_width, label='Result 1')
plt.bar(x, results_2, width=bar_width, label='Result 2')
plt.bar(x + bar_width, results_3, width=bar_width, label='Result 3')

# Labeling
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Comparison of Three Results')
plt.xticks(x, categories)
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data
categories = ['FLAN-T5-XL', 'GPT-2-Med-Finetuned', 'GPT-2-Med-Distilled']
results_1 = [10, 20, 15]
results_2 = [22, 28, 27]
results_3 = [34, 32, 33]

# Create a DataFrame to structure data for seaborn
data = pd.DataFrame({
    'Category': categories * 3,
    'Value': results_1 + results_2 + results_3,
    'Result': ['ANLI'] * 3 + ['BoolQ'] * 3 + ['Common Gen'] * 3
})

# Set the seaborn style
sns.set_theme()

# Create the bar plot
plt.figure(figsize=(8, 6))
sns.barplot(data=data, x='Category', y='Value', hue='Result', palette='tab10')

# Add title and labels
plt.title('Comparison of Three Results', fontsize=16)
plt.xlabel('Categories', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.legend(title='Results')

# Show plot
plt.show()

# %%
a = ("John", "Charles", "Mike")
b = ("Jenny", "Christy", "Monica")

#x = list(zip(a, b))

# %%
for f,g in zip(a, b):
    print(f,g)
# Out:
# John Jenny
# Charles Christy
# Mike Monica

# %%
for a,b in list(x):
    print(a,b)
# Out:
# John Jenny
# Charles Christy
# Mike Monica
